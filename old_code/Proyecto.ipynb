# %% [markdown]
# # Proyecto 13 - Quantifying Predictive Uncertainty in Autoregressive Language Models

# %% [markdown]
# Integrantes:
#
# - Benito Fuentes
# - Sebastián Vergara

# %% [markdown]
# ## 1. Introducción

# %% [markdown]
# Los modelos de lenguaje autoregresivos, como GPT-2 o GPT-3, se han convertido en herramientas fundamentales en el procesamiento del lenguaje natural. Estos modelos predicen cada palabra de una secuencia basándose en las anteriores, generando texto coherente y fluido. Sin embargo, más allá de la calidad de las predicciones, aún persiste un desafío clave: entender cuánta confianza tiene el modelo en lo que predice.
#
# En la práctica, los modelos no solo deben ser precisos, sino también capaces de estimar su propia incertidumbre. En contextos donde los errores pueden ser críticos —como en sistemas de diálogo, traducción automática o generación de código—, saber cuándo el modelo está inseguro es tan importante como la respuesta misma.
#
# Para abordar esta problemática, el proyecto busca cuantificar la incertidumbre predictiva en modelos de lenguaje mediante dos medidas provenientes de la teoría de la información:
#
# Entropía: mide la dispersión o incertidumbre general en las predicciones del modelo.
#
# Surprisal: mide el grado de sorpresa o improbabilidad de cada token según la distribución predicha.
#
# A partir de estas métricas, se pretende analizar cómo varía la confianza del modelo ante diferentes tipos de texto —por ejemplo, frases con una continuación obvia frente a frases abiertas o ambiguas— y así comprender mejor cómo razonan y calibran sus predicciones los modelos autoregresivos.
#
# En conjunto, el proyecto busca aportar una mirada interpretativa sobre el comportamiento interno de los modelos de lenguaje, desde una perspectiva basada en la teoría de la información.

# %% [markdown]
# ## 2. Marco teórico y revisión bibliográfica

# %% [markdown]
# ### 2.1. Métricas de información: entropía y surprisal

# %% [markdown]
# #### Entropía
#
# El concepto de **entropía** fue introducido por Claude Shannon (1948) en su trabajo *A Mathematical Theory of Communication* como una medida de la incertidumbre promedio asociada a una variable aleatoria.
# Formalmente, para una distribución discreta $ P(x) $:
#
# $
# H(X) = -\sum_x P(x) \log P(x)
# $
#
# En el contexto de los modelos de lenguaje autoregresivos, la entropía representa **cuán dispersa es la distribución de probabilidades** que el modelo asigna a los posibles tokens siguientes.
# - Una **entropía baja** indica que el modelo concentra su probabilidad en pocas opciones, reflejando **alta confianza**.
# - Una **entropía alta** sugiere que el modelo distribuye la probabilidad entre muchas palabras posibles, lo que implica **mayor incertidumbre**.
#
# En unidades de bits (log base 2), la entropía mide el número esperado de *preguntas sí/no* necesarias para identificar el próximo token correcto.
#
# ---
#
# #### Surprisal
#
# El **surprisal** (o “sorpresa informacional”) mide cuán inesperado es un evento según el modelo:
#
# $
# \text{Surprisal}(x) = -\log P(x)
# $
#
# En modelos de lenguaje, corresponde al negativo del logaritmo de la probabilidad asignada al token que efectivamente aparece en el texto.
# - Tokens muy probables tienen surprisal bajo.
# - Tokens inesperados (de baja probabilidad) generan surprisal alto.
#
# El surprisal refleja la sorpresa del modelo ante una observación específica, mientras que la entropía resume la incertidumbre global de toda la distribución.
#
# ---
#
# #### Relación entre entropía y surprisal
#
# Ambas métricas están íntimamente relacionadas:
# la entropía puede interpretarse como el valor esperado del surprisal bajo la distribución de probabilidad.
# Sin embargo, capturan aspectos complementarios:
#
# | Métrica | Enfoca en... | Naturaleza |
# |----------|---------------|-------------|
# | **Entropía** | Incertidumbre global del modelo | Media sobre todas las predicciones |
# | **Surprisal** | Sorpresa frente a un token concreto | Valor puntual por observación |
#
# En la práctica, el surprisal puede variar fuertemente entre tokens de una misma secuencia, mientras que la entropía varía más suavemente.
#
# ---
#
# ### 2.2. Aplicaciones de entropía y surprisal en modelos de lenguaje
#
# #### En lingüística cognitiva
#
# La teoría del surprisal ha sido ampliamente utilizada para modelar **procesos cognitivos humanos** durante la lectura.
# Estudios empíricos muestran que palabras con alto surprisal tienden a provocar **mayores tiempos de lectura o mayor carga cognitiva**.
#
# - Smith & Levy (2013) demostraron que el surprisal predice con alta precisión los tiempos de lectura en inglés, confirmando que la predicción lingüística humana se ajusta a una escala log-probabilística.
#   📄 *Smith, N. J., & Levy, R. (2013). The effect of word predictability on reading time is logarithmic.* Cognition, 128(3), 302–319. [https://doi.org/10.1016/j.cognition.2013.02.013](https://doi.org/10.1016/j.cognition.2013.02.013)
#
# - Goodkind & Bicknell (2018) mostraron que tanto el surprisal como la **reducción de entropía** explican de manera independiente la variabilidad en los tiempos de lectura.
#   📄 *Goodkind, A., & Bicknell, K. (2018). Lexical predictability during natural reading: Effects of surprisal and entropy reduction.* Cognitive Science, 42(6), 1636–1672. [https://doi.org/10.1111/cogs.12623](https://doi.org/10.1111/cogs.12623)
#
# - Futrell et al. (2024) validan las predicciones de la teoría del surprisal en múltiples idiomas, reforzando la universalidad de este fenómeno.
#   📄 *Futrell, R., et al. (2024). Testing the Predictions of Surprisal Theory in 11 Languages.* Transactions of the Association for Computational Linguistics. [https://doi.org/10.1162/tacl_a_00612](https://doi.org/10.1162/tacl_a_00612)
#
# ---
#
# #### En modelos de lenguaje y aprendizaje automático
#
# En los modelos de lenguaje modernos, la entropía y el surprisal se utilizan como **indicadores de incertidumbre y calibración** del modelo.
#
# - Hou et al. (2024) proponen una descomposición de la incertidumbre total de los modelos de lenguaje en componentes **epistémicos** (del modelo) y **aleatorios** (de los datos), usando técnicas de *input clarification ensembling*.
#   📄 *Hou, M., et al. (2024). Decomposing Uncertainty for Large Language Models through Input Clarification Ensembling.* Proceedings of the 41st International Conference on Machine Learning (ICML). [https://proceedings.mlr.press/v235/hou24b.html](https://proceedings.mlr.press/v235/hou24b.html)
#
# - Liang et al. (2024) presentan una evaluación sistemática de distintos métodos de **cuantificación de incertidumbre** para modelos de gran escala, comparando medidas basadas en entropía, probabilidad calibrada y métodos bayesianos.
#   📄 *Liang, J., et al. (2024). Benchmarking Uncertainty Quantification Methods for Large Language Models.* Transactions of the Association for Computational Linguistics. [https://doi.org/10.1162/tacl_a_00737](https://doi.org/10.1162/tacl_a_00737)
#
# - Zhang et al. (2024) estudian cómo estimar incertidumbre en escenarios de *in-context learning*, donde la fuente de incertidumbre proviene tanto del modelo como del contexto de entrada.
#   📄 *Zhang, J., et al. (2024). Uncertainty Quantification for In-Context Learning of Large Language Models.* arXiv preprint. [https://arxiv.org/abs/2402.10189](https://arxiv.org/abs/2402.10189)
#
# - Zhao et al. (2024) ofrecen una revisión extensa sobre los desafíos actuales y las aproximaciones teóricas y prácticas para cuantificar la incertidumbre en modelos de lenguaje de gran escala.
#   📄 *Zhao, C., et al. (2024). A Survey on Uncertainty Quantification of Large Language Models.* arXiv preprint. [https://arxiv.org/abs/2410.15326](https://arxiv.org/abs/2410.15326)
#
# ---
#
# ### 2.3. Críticas, desafíos y líneas de investigación
#
# A pesar de su relevancia, existen varios desafíos en la aplicación de estas métricas a modelos de lenguaje modernos:
#
# - **Dependencia del tokenizador:** la granularidad de las unidades (palabras, subpalabras o caracteres) afecta las distribuciones de probabilidad y, por ende, los valores de entropía y surprisal.
# - **Correlación entre métricas:** en lenguaje natural, la entropía y el surprisal tienden a correlacionarse fuertemente, lo que dificulta aislar sus efectos individuales.
# - **Calibración imperfecta:** las probabilidades de salida de los modelos no siempre representan bien la verdadera incertidumbre del modelo.
# - **Escalabilidad:** medir incertidumbre en modelos grandes implica un costo computacional elevado, especialmente si se analizan distribuciones completas de vocabulario.
# - **Fuentes mixtas de incertidumbre:** distinguir entre incertidumbre *epistémica* (por falta de conocimiento del modelo) y *aleatoria* (por variabilidad inherente en los datos) es un tema de investigación activa.
#
# ---
#
# ### 2.4. Síntesis
#
# La entropía y el surprisal constituyen herramientas fundamentales para interpretar la **confianza y la predictibilidad** en los modelos de lenguaje.
# Su uso se ha extendido desde la lingüística cognitiva hasta la inteligencia artificial moderna, sirviendo como un puente entre la teoría de la información y el aprendizaje profundo.
# En este proyecto, ambas métricas serán empleadas para **analizar cuantitativamente el grado de certeza** del modelo frente a distintos tipos de texto, estableciendo las bases para los experimentos de los hitos posteriores.

# %% [markdown]
# ## 3. Metodología general del proyecto

# %% [markdown]
# ## 4. Preparación del entorno

# %% [markdown]
# ## 5. Implementación de funciones base

# %% [markdown]
# ## 6. Preparación y validación

# %% [markdown]
# ## 7. Primeros experimentos

# %% [markdown]
# ## 8. Análisis completo

# %% [markdown]
# ## 9. Conclusiones globales del proyecto

# %% [markdown]
# ## 10. Anexos

# %% [markdown]
# ## Referencias

# %% [markdown]
# Goodkind, A., & Bicknell, K. (2018). Lexical predictability during natural reading: Effects of surprisal and entropy reduction. *Cognitive Science, 42*(6), 1636–1672. https://doi.org/10.1111/cogs.12623
#
# Hou, M., Liu, H., Luo, L., & Zhang, Y. (2024). Decomposing uncertainty for large language models through input clarification ensembling. *Proceedings of the 41st International Conference on Machine Learning (ICML 2024).* PMLR. https://proceedings.mlr.press/v235/hou24b.html
#
# Liang, J., Xie, Q., Kumar, A., & Song, D. (2024). Benchmarking uncertainty quantification methods for large language models. *Transactions of the Association for Computational Linguistics, 12*, 178–198. https://doi.org/10.1162/tacl_a_00737
#
# Shannon, C. E. (1948). A mathematical theory of communication. *The Bell System Technical Journal, 27*(3), 379–423. https://people.math.harvard.edu/~ctm/home/text/others/shannon/entropy/entropy.pdf
#
# Smith, N. J., & Levy, R. (2013). The effect of word predictability on reading time is logarithmic. *Cognition, 128*(3), 302–319. https://doi.org/10.1016/j.cognition.2013.02.013
#
# Futrell, R., Staub, A., & Levy, R. (2024). Testing the predictions of surprisal theory in 11 languages. *Transactions of the Association for Computational Linguistics, 12*, 1258–1274. https://doi.org/10.1162/tacl_a_00612
#
# Zhang, J., Liu, Y., Zhou, M., & Sun, M. (2024). Uncertainty quantification for in-context learning of large language models. *arXiv preprint.* https://arxiv.org/abs/2402.10189
#
# Zhao, C., Wang, X., & Liu, Q. (2024). A survey on uncertainty quantification of large language models. *arXiv preprint.* https://arxiv.org/abs/2410.15326
